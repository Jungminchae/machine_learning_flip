# %% [markdown]
# index
#
#
# gender: 성별
#
#
# car: 차량 소유 여부
#
#
# reality: 부동산 소유 여부
#
#
# child_num: 자녀 수
#
#
# income_total: 연간 소득
#
#
# income_type: 소득 분류
#
#
# 							['Commercial associate', 'Working', 'State servant', 'Pensioner', 'Student']
#
#
#
# edu_type: 교육 수준
#
#
# 							['Higher education' ,'Secondary / secondary special', 'Incomplete higher', 'Lower secondary', 'Academic degree']
#
#
#
# family_type: 결혼 여부
#
#
# 							['Married', 'Civil marriage', 'Separated', 'Single / not married', 'Widow']
#
#
#
# house_type: 생활 방식
#
#
# 							['Municipal apartment', 'House / apartment', 'With parents',
#
#
#
# 							 'Co-op apartment', 'Rented apartment', 'Office apartment']
#
#
#
# DAYS_BIRTH: 출생일
#
#
# 							데이터 수집 당시 (0)부터 역으로 셈, 즉, -1은 데이터 수집일 하루 전에 태어났음을 의미
#
#
#
# DAYS_EMPLOYED: 업무 시작일
#
#
# 							데이터 수집 당시 (0)부터 역으로 셈, 즉, -1은 데이터 수집일 하루 전부터 일을 시작함을 의미
#
#
#
# 							양수 값은 고용되지 않은 상태를 의미함
#
#
#
# FLAG_MOBIL: 핸드폰 소유 여부
#
#
# work_phone: 업무용 전화 소유 여부
#
#
# phone: 전화 소유 여부
#
#
# email: 이메일 소유 여부
#
#
# occyp_type: 직업 유형
#
#
# family_size: 가족 규모
#
#
# begin_month: 신용카드 발급 월
#
#
# 							데이터 수집 당시 (0)부터 역으로 셈, 즉, -1은 데이터 수집일 한 달 전에 신용카드를 발급함을 의미
#
#
#
#
#
#
#
# credit: 사용자의 신용카드 대금 연체를 기준의 신용도
#
#
# 							=> 낮을 수록 높은 신용의 신용카드 사용자를 의미함

# %%
import os
import warnings
import pandas as pd 
import numpy as np

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
plt.style.use("ggplot")

# %%
warnings.filterwarnings('ignore')

# %%
data_path = os.listdir('data')

# %%
data_path
# Out:
# ['test.csv', 'train.csv', 'sample_submission.csv']

# %%
train_data = pd.read_csv(os.path.join("data" ,data_path[1]))
test_data = pd.read_csv(os.path.join("data", data_path[0]))

# %%
submission = pd.read_csv(os.path.join("data", data_path[2]))

# %%
submission
# Out:
#       index  0  1  2
# 0     26457  0  0  0
# 1     26458  0  0  0
# 2     26459  0  0  0
# 3     26460  0  0  0
# 4     26461  0  0  0
# ...     ... .. .. ..
# 9995  36452  0  0  0
# 9996  36453  0  0  0
# 9997  36454  0  0  0
# 9998  36455  0  0  0
# 9999  36456  0  0  0
#
# [10000 rows x 4 columns]

# %%
# head
train_data.head()
# Out:
#    index gender car reality  child_num  income_total           income_type  \
# 0      0      F   N       N          0      202500.0  Commercial associate
# 1      1      F   N       Y          1      247500.0  Commercial associate
# 2      2      M   Y       Y          0      450000.0               Working
# 3      3      F   N       Y          0      202500.0  Commercial associate
# 4      4      F   Y       Y          0      157500.0         State servant
#
#                         edu_type     family_type           house_type  \
# 0               Higher education         Married  Municipal apartment
# 1  Secondary / secondary special  Civil marriage    House / apartment
# 2               Higher education         Married    House / apartment
# 3  Secondary / secondary special         Married    House / apartment
# 4               Higher education         Married    House / apartment
#
#    DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  \
# 0      -13899          -4709           1           0      0      0
# 1      -11380          -1540           1           0      0      1
# 2      -19087          -4434           1           0      1      0
# 3      -15088          -2092           1           0      1      0
# 4      -15037          -2105           1           0      0      0
#
#     occyp_type  family_size  begin_month  credit
# 0          NaN          2.0         -6.0     1.0
# 1     Laborers          3.0         -5.0     1.0
# 2     Managers          2.0        -22.0     2.0
# 3  Sales staff          2.0        -37.0     0.0
# 4     Managers          2.0        -26.0     2.0

# %%
test_data.head()
# Out:
#    index gender car reality  child_num  income_total           income_type  \
# 0  26457      M   Y       N          0      112500.0             Pensioner
# 1  26458      F   N       Y          0      135000.0         State servant
# 2  26459      F   N       Y          0       69372.0               Working
# 3  26460      M   Y       N          0      112500.0  Commercial associate
# 4  26461      F   Y       Y          0      225000.0         State servant
#
#                         edu_type     family_type         house_type  \
# 0  Secondary / secondary special  Civil marriage  House / apartment
# 1               Higher education         Married  House / apartment
# 2  Secondary / secondary special         Married  House / apartment
# 3  Secondary / secondary special         Married  House / apartment
# 4               Higher education         Married  House / apartment
#
#    DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  \
# 0      -21990         365243           1           0      1      0
# 1      -18964          -8671           1           0      1      0
# 2      -15887           -217           1           1      1      0
# 3      -19270          -2531           1           1      0      0
# 4      -17822          -9385           1           1      0      0
#
#    occyp_type  family_size  begin_month
# 0         NaN          2.0        -60.0
# 1  Core staff          2.0        -36.0
# 2    Laborers          2.0        -40.0
# 3     Drivers          2.0        -41.0
# 4    Managers          2.0         -8.0

# %%
set(train_data.columns) - set(test_data.columns)
# Out:
# {'credit'}

# %%
train_data.shape, test_data.shape
# Out:
# ((26457, 20), (10000, 19))

# %%
train_data.drop_duplicates().shape
# Out:
# (26457, 20)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          26457 non-null  int64
#  1   gender         26457 non-null  object
#  2   car            26457 non-null  object
#  3   reality        26457 non-null  object
#  4   child_num      26457 non-null  int64
#  5   income_total   26457 non-null  float64
#  6   income_type    26457 non-null  object
#  7   edu_type       26457 non-null  object
#  8   family_type    26457 non-null  object
#  9   house_type     26457 non-null  object
#  10  DAYS_BIRTH     26457 non-null  int64
#  11  DAYS_EMPLOYED  26457 non-null  int64
#  12  FLAG_MOBIL     26457 non-null  int64
#  13  work_phone     26457 non-null  int64
#  14  phone          26457 non-null  int64
#  15  email          26457 non-null  int64
#  16  occyp_type     18286 non-null  object
#  17  family_size    26457 non-null  float64
#  18  begin_month    26457 non-null  float64
#  19  credit         26457 non-null  float64
# dtypes: float64(4), int64(8), object(8)
# memory usage: 4.0+ MB

# %%
# na
(train_data.isna().sum() / len(train_data) ) * 100
# Out:
# index             0.000000
# gender            0.000000
# car               0.000000
# reality           0.000000
# child_num         0.000000
# income_total      0.000000
# income_type       0.000000
# edu_type          0.000000
# family_type       0.000000
# house_type        0.000000
# DAYS_BIRTH        0.000000
# DAYS_EMPLOYED     0.000000
# FLAG_MOBIL        0.000000
# work_phone        0.000000
# phone             0.000000
# email             0.000000
# occyp_type       30.884076
# family_size       0.000000
# begin_month       0.000000
# credit            0.000000
# dtype: float64

# %%
(test_data.isna().sum() / len(test_data)) * 100
# Out:
# index             0.00
# gender            0.00
# car               0.00
# reality           0.00
# child_num         0.00
# income_total      0.00
# income_type       0.00
# edu_type          0.00
# family_type       0.00
# house_type        0.00
# DAYS_BIRTH        0.00
# DAYS_EMPLOYED     0.00
# FLAG_MOBIL        0.00
# work_phone        0.00
# phone             0.00
# email             0.00
# occyp_type       31.52
# family_size       0.00
# begin_month       0.00
# dtype: float64

# %%
# train, test concat
dataset = pd.concat([train_data.drop("credit" , axis=1), test_data])

# %%
dataset.shape
# Out:
# (36457, 19)

# %%
for col in dataset.columns:
    print(f"{col} : The number of unique : {dataset[col].nunique()}")
    print()
# Out:
# index : The number of unique : 36457
#
# gender : The number of unique : 2
#
# car : The number of unique : 2
#
# reality : The number of unique : 2
#
# child_num : The number of unique : 9
#
# income_total : The number of unique : 265
#
# income_type : The number of unique : 5
#
# edu_type : The number of unique : 5
#
# family_type : The number of unique : 5
#
# house_type : The number of unique : 6
#
# DAYS_BIRTH : The number of unique : 7183
#
# DAYS_EMPLOYED : The number of unique : 3640
#
# FLAG_MOBIL : The number of unique : 1
#
# work_phone : The number of unique : 2
#
# phone : The number of unique : 2
#
# email : The number of unique : 2
#
# occyp_type : The number of unique : 18
#
# family_size : The number of unique : 10
#
# begin_month : The number of unique : 61

# %%
cat_cols = "gender car reality child_num income_type edu_type family_type house_type FLAG_MOBIL work_phone phone email occyp_type family_size".split()

# %%
cat_cols
# Out:
# ['gender',
#  'car',
#  'reality',
#  'child_num',
#  'income_type',
#  'edu_type',
#  'family_type',
#  'house_type',
#  'FLAG_MOBIL',
#  'work_phone',
#  'phone',
#  'email',
#  'occyp_type',
#  'family_size']

# %%
not_cat_cols = list(set(dataset.columns) - set(cat_cols))

# %%
not_cat_cols
# Out:
# ['index', 'begin_month', 'DAYS_EMPLOYED', 'DAYS_BIRTH', 'income_total']

# %%
num = len(cat_cols) // 2
plt.figure(figsize=(30,20))
for i, col in enumerate(cat_cols):
    plt.subplot(num, 2, i+1)
    sns.countplot(data=dataset, x=col)
    plt.title(f"{col}'s countplot'")
    plt.xticks(rotation=45, fontsize=14)
    plt.subplots_adjust(wspace=0.3, hspace=1.2)

plt.show()

# %%
for col in not_cat_cols:
    if col == "index":
        continue
    sns.distplot(dataset[col])
    plt.show()

# %%
sns.distplot(train_data["credit"])
# Out:
# <AxesSubplot:xlabel='credit', ylabel='Density'>

# %%
train_data["credit"].unique()
# Out:
# array([1., 2., 0.])

# %%
sns.countplot(train_data["credit"])
# Out:
# <AxesSubplot:xlabel='credit', ylabel='count'>

# %%
cor = train_data.corr()
plt.figure(figsize=(12,12))
sns.heatmap(cor, annot=True)
# Out:
# <AxesSubplot:>

# %%
train_data[train_data['child_num'] >= 14]
# Out:
#        index gender car reality  child_num  income_total income_type  \
# 8462    8462      M   Y       Y         14      225000.0     Working
# 9021    9021      M   Y       Y         14      225000.0     Working
# 10731  10731      F   N       Y         19      112500.0     Working
# 25390  25390      M   Y       Y         14      225000.0     Working
#
#                             edu_type           family_type         house_type  \
# 8462   Secondary / secondary special             Separated  House / apartment
# 9021   Secondary / secondary special             Separated  House / apartment
# 10731  Secondary / secondary special  Single / not married  House / apartment
# 25390  Secondary / secondary special             Separated  House / apartment
#
#        DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  \
# 8462       -17754          -1689           1           0      0      0
# 9021       -17754          -1689           1           0      0      0
# 10731      -11057          -1853           1           1      1      0
# 25390      -17754          -1689           1           0      0      0
#
#                  occyp_type  family_size  begin_month  credit
# 8462                Drivers         15.0         -7.0     2.0
# 9021                Drivers         15.0        -58.0     2.0
# 10731  Waiters/barmen staff         20.0         -5.0     2.0
# 25390               Drivers         15.0        -43.0     2.0

# %%
test_data[test_data['child_num'] > 3]
# Out:
#       index gender car reality  child_num  income_total           income_type  \
# 387   26844      F   N       Y          5      157500.0               Working
# 494   26951      M   Y       Y          5      202500.0               Working
# 1574  28031      F   N       Y          4      261000.0               Working
# 2543  29000      M   Y       Y          4      157500.0               Working
# 3772  30229      F   Y       Y          4      157500.0         State servant
# 4130  30587      F   Y       Y          4      112500.0               Working
# 4234  30691      M   Y       Y          5      202500.0               Working
# 4807  31264      F   N       Y          5      157500.0               Working
# 6105  32562      M   Y       N          5      211500.0               Working
# 6521  32978      M   Y       Y          4       67500.0               Working
# 6683  33140      F   Y       Y          4      112500.0               Working
# 6858  33315      F   Y       Y          4      157500.0         State servant
# 6894  33351      F   N       Y          5      157500.0               Working
# 6902  33359      F   Y       Y          4      112500.0               Working
# 7297  33754      F   N       Y          5      157500.0               Working
# 7772  34229      F   Y       Y          4      292500.0               Working
# 7907  34364      M   Y       Y          5      202500.0               Working
# 8077  34534      M   Y       Y          4      157500.0               Working
# 8198  34655      F   N       N          4      112500.0  Commercial associate
# 8656  35113      F   Y       N          4      202500.0               Working
# 8866  35323      F   Y       Y          4      112500.0               Working
# 9038  35495      M   Y       Y          5      202500.0               Working
# 9082  35539      F   Y       Y          4      112500.0               Working
# 9099  35556      F   Y       N          5      112500.0               Working
# 9818  36275      M   Y       N          4      202500.0  Commercial associate
# 9964  36421      M   Y       Y          4      157500.0               Working
#
#                            edu_type family_type         house_type  \
# 387   Secondary / secondary special     Married  House / apartment
# 494   Secondary / secondary special     Married    Co-op apartment
# 1574  Secondary / secondary special     Married  House / apartment
# 2543               Higher education     Married  House / apartment
# 3772  Secondary / secondary special   Separated  House / apartment
# 4130               Higher education     Married  House / apartment
# 4234  Secondary / secondary special     Married    Co-op apartment
# 4807  Secondary / secondary special     Married  House / apartment
# 6105  Secondary / secondary special     Married  House / apartment
# 6521  Secondary / secondary special     Married  House / apartment
# 6683               Higher education     Married  House / apartment
# 6858  Secondary / secondary special   Separated  House / apartment
# 6894  Secondary / secondary special     Married  House / apartment
# 6902               Higher education     Married  House / apartment
# 7297  Secondary / secondary special     Married  House / apartment
# 7772  Secondary / secondary special     Married  House / apartment
# 7907  Secondary / secondary special     Married    Co-op apartment
# 8077               Higher education     Married  House / apartment
# 8198  Secondary / secondary special     Married  House / apartment
# 8656              Incomplete higher     Married  House / apartment
# 8866  Secondary / secondary special     Married  House / apartment
# 9038  Secondary / secondary special     Married    Co-op apartment
# 9082  Secondary / secondary special     Married  House / apartment
# 9099  Secondary / secondary special     Married  House / apartment
# 9818  Secondary / secondary special     Married  House / apartment
# 9964               Higher education     Married  House / apartment
#
#       DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  \
# 387       -13039          -3375           1           0      0      0
# 494       -11384          -2727           1           0      0      0
# 1574      -12475          -1588           1           0      0      0
# 2543      -11380          -1734           1           0      0      0
# 3772      -13994          -4185           1           1      1      0
# 4130      -13671          -1974           1           0      0      0
# 4234      -11384          -2727           1           0      0      0
# 4807      -13039          -3375           1           0      0      0
# 6105      -13817          -1892           1           1      0      0
# 6521      -13740          -2064           1           0      0      0
# 6683      -13671          -1974           1           0      0      0
# 6858      -13994          -4185           1           1      1      0
# 6894      -13039          -3375           1           0      0      0
# 6902      -13671          -1974           1           0      0      0
# 7297      -13039          -3375           1           0      0      0
# 7772      -11408          -1023           1           0      0      1
# 7907      -11384          -2727           1           0      0      0
# 8077      -11380          -1734           1           0      0      0
# 8198      -13015          -1375           1           1      1      0
# 8656      -12448          -4395           1           0      0      0
# 8866      -13754          -4169           1           0      0      0
# 9038      -11384          -2727           1           0      0      0
# 9082      -13754          -4169           1           0      0      0
# 9099      -12102          -1346           1           1      0      0
# 9818      -15328          -2578           1           0      0      0
# 9964      -11380          -1734           1           0      0      0
#
#                  occyp_type  family_size  begin_month
# 387                Laborers          7.0         -9.0
# 494                Managers          7.0        -55.0
# 1574  High skill tech staff          6.0        -41.0
# 2543               Managers          6.0        -20.0
# 3772         Security staff          5.0         -4.0
# 4130             Core staff          6.0        -59.0
# 4234               Managers          7.0        -37.0
# 4807               Laborers          7.0        -11.0
# 6105               Laborers          7.0        -23.0
# 6521             Core staff          6.0         -7.0
# 6683             Core staff          6.0        -42.0
# 6858         Security staff          5.0         -8.0
# 6894               Laborers          7.0         -9.0
# 6902             Core staff          6.0        -38.0
# 7297               Laborers          7.0        -19.0
# 7772                    NaN          6.0        -13.0
# 7907               Managers          7.0         -2.0
# 8077               Managers          6.0         -3.0
# 8198                    NaN          6.0        -52.0
# 8656             Core staff          6.0        -26.0
# 8866         Medicine staff          6.0        -23.0
# 9038               Managers          7.0        -26.0
# 9082         Medicine staff          6.0         -9.0
# 9099                    NaN          7.0        -24.0
# 9818         Security staff          6.0        -14.0
# 9964               Managers          6.0        -11.0

# %%
dataset['child_num'].unique()
# Out:
# array([ 0,  1,  2,  3,  4,  5, 14, 19,  7])

# %%
test_data['child_num'].unique()
# Out:
# array([0, 1, 2, 3, 5, 4])

# %%
# 나이 추가
dataset['AGE'] = -1 * (dataset['DAYS_BIRTH'] // 365)

# %%
# 31살에 자식이 19명 가능? 
# 49살에 자식이 14명 가능?
dataset[train_data["child_num"] >= 14]
# Out:
#        index gender car reality  child_num  income_total  \
# 8462    8462      M   Y       Y         14      225000.0
# 9021    9021      M   Y       Y         14      225000.0
# 10731  10731      F   N       Y         19      112500.0
# 25390  25390      M   Y       Y         14      225000.0
# 8462   34919      F   Y       Y          0      247500.0
# 9021   35478      F   N       Y          0      292500.0
#
#                 income_type                       edu_type  \
# 8462                Working  Secondary / secondary special
# 9021                Working  Secondary / secondary special
# 10731               Working  Secondary / secondary special
# 25390               Working  Secondary / secondary special
# 8462   Commercial associate               Higher education
# 9021   Commercial associate               Higher education
#
#                 family_type         house_type  DAYS_BIRTH  DAYS_EMPLOYED  \
# 8462              Separated  House / apartment      -17754          -1689
# 9021              Separated  House / apartment      -17754          -1689
# 10731  Single / not married  House / apartment      -11057          -1853
# 25390             Separated  House / apartment      -17754          -1689
# 8462                Married  House / apartment      -14462          -1871
# 9021                Married  House / apartment      -18942          -4854
#
#        FLAG_MOBIL  work_phone  phone  email            occyp_type  \
# 8462            1           0      0      0               Drivers
# 9021            1           0      0      0               Drivers
# 10731           1           1      1      0  Waiters/barmen staff
# 25390           1           0      0      0               Drivers
# 8462            1           0      1      1                   NaN
# 9021            1           1      0      0           Sales staff
#
#        family_size  begin_month  AGE
# 8462          15.0         -7.0   49
# 9021          15.0        -58.0   49
# 10731         20.0         -5.0   31
# 25390         15.0        -43.0   49
# 8462           2.0        -31.0   40
# 9021           2.0        -56.0   52

# %%
# 신용카드를 몇 년동안 썼는지
dataset["how_long_credit"] = -1 * (dataset["begin_month"] / 12)
dataset["how_long_credit"] = round(dataset["how_long_credit"], 2)

# %%
# 근속 년수
dataset["how_long_work"] = -1 * (dataset["DAYS_EMPLOYED"] / 365)
dataset["how_long_work"] = round(dataset["how_long_work"], 2)

# %%
dataset[dataset["how_long_work"] < 0]
# Out:
#       index gender car reality  child_num  income_total income_type  \
# 14       14      F   N       Y          0      157500.0   Pensioner
# 18       18      F   N       Y          0      216000.0   Pensioner
# 21       21      F   N       N          0      157500.0   Pensioner
# 24       24      F   N       N          0      202500.0   Pensioner
# 46       46      F   N       N          0      135000.0   Pensioner
# ...     ...    ...  ..     ...        ...           ...         ...
# 9968  36425      F   Y       Y          0      135000.0   Pensioner
# 9981  36438      M   Y       Y          0      135000.0   Pensioner
# 9988  36445      F   N       N          0      117000.0   Pensioner
# 9992  36449      F   N       Y          0      180000.0   Pensioner
# 9994  36451      M   Y       Y          0      131400.0   Pensioner
#
#                            edu_type           family_type         house_type  \
# 14    Secondary / secondary special  Single / not married  House / apartment
# 18    Secondary / secondary special               Married  House / apartment
# 21    Secondary / secondary special               Married  House / apartment
# 24    Secondary / secondary special  Single / not married  House / apartment
# 46    Secondary / secondary special                 Widow  House / apartment
# ...                             ...                   ...                ...
# 9968  Secondary / secondary special               Married  House / apartment
# 9981  Secondary / secondary special               Married  House / apartment
# 9988  Secondary / secondary special                 Widow  House / apartment
# 9992  Secondary / secondary special               Married  House / apartment
# 9994  Secondary / secondary special               Married  House / apartment
#
#       ...  FLAG_MOBIL  work_phone  phone  email  occyp_type  family_size  \
# 14    ...           1           0      1      0         NaN          1.0
# 18    ...           1           0      0      0         NaN          2.0
# 21    ...           1           0      1      0         NaN          2.0
# 24    ...           1           0      1      0         NaN          1.0
# 46    ...           1           0      1      0         NaN          1.0
# ...   ...         ...         ...    ...    ...         ...          ...
# 9968  ...           1           0      1      0         NaN          2.0
# 9981  ...           1           0      1      0         NaN          2.0
# 9988  ...           1           0      0      0         NaN          1.0
# 9992  ...           1           0      0      0         NaN          2.0
# 9994  ...           1           0      0      0         NaN          2.0
#
#      begin_month  AGE  how_long_credit  how_long_work
# 14         -41.0   63             3.42       -1000.67
# 18         -37.0   64             3.08       -1000.67
# 21          -7.0   59             0.58       -1000.67
# 24          -5.0   62             0.42       -1000.67
# 46         -24.0   58             2.00       -1000.67
# ...          ...  ...              ...            ...
# 9968       -43.0   56             3.58       -1000.67
# 9981       -49.0   65             4.08       -1000.67
# 9988       -27.0   54             2.25       -1000.67
# 9992       -30.0   63             2.50       -1000.67
# 9994        -3.0   65             0.25       -1000.67
#
# [6135 rows x 22 columns]

# %%
# 같은 사람 데이터도 존재 
# 결혼 안했다가 결혼을 한 경우도 생기고 소득이 증가한 경우도 생김
dataset[dataset["how_long_work"] < 0].drop(["index", "begin_month", "how_long_credit"],axis=1).drop_duplicates()
# Out:
#      gender car reality  child_num  income_total income_type  \
# 14        F   N       Y          0      157500.0   Pensioner
# 18        F   N       Y          0      216000.0   Pensioner
# 21        F   N       N          0      157500.0   Pensioner
# 24        F   N       N          0      202500.0   Pensioner
# 46        F   N       N          0      135000.0   Pensioner
# ...     ...  ..     ...        ...           ...         ...
# 9782      F   N       Y          0      112500.0   Pensioner
# 9944      F   N       Y          0      360000.0   Pensioner
# 9946      F   N       N          0      193500.0   Pensioner
# 9954      F   Y       Y          0      225000.0   Pensioner
# 9988      F   N       N          0      117000.0   Pensioner
#
#                            edu_type           family_type         house_type  \
# 14    Secondary / secondary special  Single / not married  House / apartment
# 18    Secondary / secondary special               Married  House / apartment
# 21    Secondary / secondary special               Married  House / apartment
# 24    Secondary / secondary special  Single / not married  House / apartment
# 46    Secondary / secondary special                 Widow  House / apartment
# ...                             ...                   ...                ...
# 9782  Secondary / secondary special               Married  House / apartment
# 9944  Secondary / secondary special               Married  House / apartment
# 9946               Higher education                 Widow  House / apartment
# 9954  Secondary / secondary special               Married  House / apartment
# 9988  Secondary / secondary special                 Widow  House / apartment
#
#       DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  \
# 14        -22922         365243           1           0      1      0
# 18        -23113         365243           1           0      0      0
# 21        -21253         365243           1           0      1      0
# 24        -22361         365243           1           0      1      0
# 46        -21100         365243           1           0      1      0
# ...          ...            ...         ...         ...    ...    ...
# 9782      -13367         365243           1           0      1      0
# 9944      -19390         365243           1           0      1      0
# 9946      -22010         365243           1           0      0      0
# 9954      -23013         365243           1           0      0      0
# 9988      -19698         365243           1           0      0      0
#
#      occyp_type  family_size  AGE  how_long_work
# 14          NaN          1.0   63       -1000.67
# 18          NaN          2.0   64       -1000.67
# 21          NaN          2.0   59       -1000.67
# 24          NaN          1.0   62       -1000.67
# 46          NaN          1.0   58       -1000.67
# ...         ...          ...  ...            ...
# 9782        NaN          2.0   37       -1000.67
# 9944        NaN          2.0   54       -1000.67
# 9946        NaN          1.0   61       -1000.67
# 9954        NaN          2.0   64       -1000.67
# 9988        NaN          1.0   54       -1000.67
#
# [1699 rows x 19 columns]

# %%
# 이쯤에서 통계량확인 한 번
dataset.describe().T
# Out:
#                    count           mean            std       min        25%  \
# index            36457.0   18228.000000   10524.373719      0.00    9114.00
# child_num        36457.0       0.430315       0.742367      0.00       0.00
# income_total     36457.0  186685.736662  101789.226482  27000.00  121500.00
# DAYS_BIRTH       36457.0  -15975.173382    4200.549944 -25152.00  -19438.00
# DAYS_EMPLOYED    36457.0   59262.935568  137651.334859 -15713.00   -3153.00
# FLAG_MOBIL       36457.0       1.000000       0.000000      1.00       1.00
# work_phone       36457.0       0.225526       0.417934      0.00       0.00
# phone            36457.0       0.294813       0.455965      0.00       0.00
# email            36457.0       0.089722       0.285787      0.00       0.00
# family_size      36457.0       2.198453       0.911686      1.00       2.00
# begin_month      36457.0     -26.164193      16.501854    -60.00     -39.00
# AGE              36457.0      44.257865      11.509626     21.00      35.00
# how_long_credit  36457.0       2.180342       1.375184     -0.00       1.00
# how_long_work    36457.0    -162.364823     377.128577  -1000.67       1.12
#
#                        50%        75%         max
# index             18228.00   27342.00    36456.00
# child_num             0.00       1.00       19.00
# income_total     157500.00  225000.00  1575000.00
# DAYS_BIRTH       -15563.00  -12462.00    -7489.00
# DAYS_EMPLOYED     -1552.00    -408.00   365243.00
# FLAG_MOBIL            1.00       1.00        1.00
# work_phone            0.00       0.00        1.00
# phone                 0.00       1.00        1.00
# email                 0.00       0.00        1.00
# family_size           2.00       3.00       20.00
# begin_month         -24.00     -12.00        0.00
# AGE                  43.00      54.00       69.00
# how_long_credit       2.00       3.25        5.00
# how_long_work         4.25       8.64       43.05

# %%
# merried랑 civil merriage랑 차이가 뭐냐
sns.countplot(train_data[train_data["family_type"] =="Married"]['credit'])
# Out:
# <AxesSubplot:xlabel='credit', ylabel='count'>

# %%
sns.countplot(train_data[train_data["family_type"] =="Civil marriage"]['credit'])
# Out:
# <AxesSubplot:xlabel='credit', ylabel='count'>

# %%
# married랑 Civil marriage 하나로 맞춰주자
dataset["family_type"] = dataset["family_type"].map(lambda x : "Married" if x == "Civil marriage" else x)

# %%
dataset["family_type"].unique()
# Out:
# array(['Married', 'Separated', 'Single / not married', 'Widow'],
#       dtype=object)

# %%
# income이 꼭 높아야만 신용이 좋은 것은 아님
train_data.groupby("credit")['income_total'].mean()
# Out:
# credit
# 0.0    190807.582402
# 1.0    181122.701532
# 2.0    188925.666991
# Name: income_total, dtype: float64

# %%
# occyp_type
occyp = dataset["occyp_type"].unique()
occyp
# Out:
# array([nan, 'Laborers', 'Managers', 'Sales staff',
#        'High skill tech staff', 'Core staff', 'Drivers', 'Medicine staff',
#        'Accountants', 'Realty agents', 'Security staff', 'Cleaning staff',
#        'Private service staff', 'Cooking staff', 'Secretaries',
#        'HR staff', 'IT staff', 'Low-skill Laborers',
#        'Waiters/barmen staff'], dtype=object)

# %%
for i in occyp:
    if type(i) == float:
        continue
    temp = dataset[dataset["occyp_type"] == i].groupby("occyp_type")["income_total"].mean()
    display(temp)
# Out:
# occyp_type
# Laborers    179794.282402
# Name: income_total, dtype: float64
# occyp_type
# Managers    279117.292829
# Name: income_total, dtype: float64
# occyp_type
# Sales staff    174984.897848
# Name: income_total, dtype: float64
# occyp_type
# High skill tech staff    196053.579176
# Name: income_total, dtype: float64
# occyp_type
# Core staff    190172.786967
# Name: income_total, dtype: float64
# occyp_type
# Drivers    209797.240412
# Name: income_total, dtype: float64
# occyp_type
# Medicine staff    166114.618061
# Name: income_total, dtype: float64
# occyp_type
# Accountants    202463.865834
# Name: income_total, dtype: float64
# occyp_type
# Realty agents    247500.0
# Name: income_total, dtype: float64
# occyp_type
# Security staff    177037.753378
# Name: income_total, dtype: float64
# occyp_type
# Cleaning staff    149141.107078
# Name: income_total, dtype: float64
# occyp_type
# Private service staff    198863.372093
# Name: income_total, dtype: float64
# occyp_type
# Cooking staff    146517.251908
# Name: income_total, dtype: float64
# occyp_type
# Secretaries    168079.470199
# Name: income_total, dtype: float64
# occyp_type
# HR staff    193764.705882
# Name: income_total, dtype: float64
# occyp_type
# IT staff    199860.0
# Name: income_total, dtype: float64
# occyp_type
# Low-skill Laborers    133920.0
# Name: income_total, dtype: float64
# occyp_type
# Waiters/barmen staff    156206.896552
# Name: income_total, dtype: float64

# %%
temp = train_data.groupby(["occyp_type","credit"])["income_total"].count().unstack()

# %%
temp_list = []
for i in temp.itertuples():
    print(i)
    temp_list.append(sum(i[1:]))

temp["total"] = temp_list
# Out:
# Pandas(Index='Accountants', _1=118, _2=227, _3=557)
# Pandas(Index='Cleaning staff', _1=40, _2=93, _3=270)
# Pandas(Index='Cooking staff', _1=58, _2=110, _3=289)
# Pandas(Index='Core staff', _1=347, _2=622, _3=1677)
# Pandas(Index='Drivers', _1=187, _2=358, _3=1030)
# Pandas(Index='HR staff', _1=7, _2=4, _3=51)
# Pandas(Index='High skill tech staff', _1=123, _2=270, _3=647)
# Pandas(Index='IT staff', _1=8, _2=10, _3=23)
# Pandas(Index='Laborers', _1=586, _2=1082, _3=2844)
# Pandas(Index='Low-skill Laborers', _1=22, _2=21, _3=84)
# Pandas(Index='Managers', _1=280, _2=458, _3=1429)
# Pandas(Index='Medicine staff', _1=83, _2=191, _3=590)
# Pandas(Index='No Jobs', _1=536, _2=1084, _3=2820)
# Pandas(Index='Private service staff', _1=35, _2=55, _3=153)
# Pandas(Index='Realty agents', _1=10, _2=9, _3=44)
# Pandas(Index='Sales staff', _1=293, _2=650, _3=1596)
# Pandas(Index='Secretaries', _1=9, _2=31, _3=57)
# Pandas(Index='Security staff', _1=39, _2=88, _3=297)
# Pandas(Index='Waiters/barmen staff', _1=10, _2=50, _3=64)

# %%
for col in temp.columns:
    if col == "total":
        continue
    temp[col] = (temp[col] / temp["total"]) * 100

# %%
# 직업이랑 신용등급이랑 그렇게 큰 관련이 없는걸로
temp
# Out:
# credit                       0.0        1.0        2.0  total
# occyp_type
# Accountants            13.082040  25.166297  61.751663    902
# Cleaning staff          9.925558  23.076923  66.997519    403
# Cooking staff          12.691466  24.070022  63.238512    457
# Core staff             13.114135  23.507181  63.378685   2646
# Drivers                11.873016  22.730159  65.396825   1575
# HR staff               11.290323   6.451613  82.258065     62
# High skill tech staff  11.826923  25.961538  62.211538   1040
# IT staff               19.512195  24.390244  56.097561     41
# Laborers               12.987589  23.980496  63.031915   4512
# Low-skill Laborers     17.322835  16.535433  66.141732    127
# Managers               12.921089  21.135210  65.943701   2167
# Medicine staff          9.606481  22.106481  68.287037    864
# Private service staff  14.403292  22.633745  62.962963    243
# Realty agents          15.873016  14.285714  69.841270     63
# Sales staff            11.539976  25.600630  62.859393   2539
# Secretaries             9.278351  31.958763  58.762887     97
# Security staff          9.198113  20.754717  70.047170    424
# Waiters/barmen staff    8.064516  40.322581  51.612903    124

# %%
(dataset["house_type"].value_counts() / len(dataset)) * 100
# Out:
# House / apartment      89.277779
# With parents            4.871492
# Municipal apartment     3.094056
# Rented apartment        1.577201
# Office apartment        0.718655
# Co-op apartment         0.460817
# Name: house_type, dtype: float64

# %%
train_data.groupby(["house_type", "credit"]).size()
# Out:
# house_type           credit
# Co-op apartment      0.0          14
#                      1.0          30
#                      2.0          66
# House / apartment    0.0        2873
#                      1.0        5569
#                      2.0       15211
# Municipal apartment  0.0         110
#                      1.0         160
#                      2.0         548
# Office apartment     0.0          24
#                      1.0          48
#                      2.0         118
# Rented apartment     0.0          50
#                      1.0         147
#                      2.0         232
# With parents         0.0         151
#                      1.0         313
#                      2.0         793
# dtype: int64

# %%
train_data.groupby(["child_num", "credit"]).size()
# Out:
# child_num  credit
# 0          0.0        2233
#            1.0        4322
#            2.0       11785
# 1          0.0         682
#            1.0        1313
#            2.0        3391
# 2          0.0         268
#            1.0         535
#            2.0        1559
# 3          0.0          29
#            1.0          79
#            2.0         198
# 4          0.0           8
#            1.0          12
#            2.0          27
# 5          0.0           2
#            1.0           6
#            2.0           2
# 7          2.0           2
# 14         2.0           3
# 19         2.0           1
# dtype: int64

# %%
# 아 모르겠다 일단 모델이나 한 번 돌려보자
dataset = dataset.reset_index(drop=True)
dataset = dataset.drop([8462, 9021, 10731, 25390]).reset_index(drop=True)

# %%
dataset2 = dataset.copy()
# dataset = dataset.fillna("Laborers")

# %%
dataset[dataset["how_long_work"] < 0]['income_type'].unique()
# Out:
# array(['Pensioner'], dtype=object)

# %%
dataset[dataset["how_long_work"] < 0]["AGE"].min()
# Out:
# 23

# %%
dataset[dataset["how_long_work"] < 0]["AGE"].mean()
# Out:
# 60.12942135289324

# %%
# Na 채우기
dataset[dataset["how_long_work"] < 0] = dataset[dataset["how_long_work"] < 0].fillna("No Jobs")

# %%
dataset[dataset['income_type'] == "Pensioner"] = dataset[dataset['income_type'] == "Pensioner"].fillna("No Jobs")

# %%
dataset[dataset['income_type'] == 'Student'] = dataset[dataset['income_type'] == 'Student'].fillna('No Jobs')

# %%
temp = dataset[dataset['income_type'] == "Working"]

# %%
temp_index = temp[temp['occyp_type'].isna() == True].index

# %%
dataset.iloc[temp_index] = dataset.iloc[temp_index].fillna("Laborers")

# %%
dataset[dataset["income_type"] == "State servant"] = dataset[dataset["income_type"] == "State servant"].fillna("other공무원")

# %%
dataset[dataset["income_type"] == "Commercial associate"] = dataset[dataset["income_type"] == "Commercial associate"].fillna("Laborers")

# %%
dataset.head()
# Out:
#    index gender car reality  child_num  income_total           income_type  \
# 0      0      F   N       N          0      202500.0  Commercial associate
# 1      1      F   N       Y          1      247500.0  Commercial associate
# 2      2      M   Y       Y          0      450000.0               Working
# 3      3      F   N       Y          0      202500.0  Commercial associate
# 4      4      F   Y       Y          0      157500.0         State servant
#
#                         edu_type family_type           house_type  ...  \
# 0               Higher education     Married  Municipal apartment  ...
# 1  Secondary / secondary special     Married    House / apartment  ...
# 2               Higher education     Married    House / apartment  ...
# 3  Secondary / secondary special     Married    House / apartment  ...
# 4               Higher education     Married    House / apartment  ...
#
#    FLAG_MOBIL  work_phone  phone  email   occyp_type  family_size begin_month  \
# 0           1           0      0      0     Laborers          2.0        -6.0
# 1           1           0      0      1     Laborers          3.0        -5.0
# 2           1           0      1      0     Managers          2.0       -22.0
# 3           1           0      1      0  Sales staff          2.0       -37.0
# 4           1           0      0      0     Managers          2.0       -26.0
#
#    AGE  how_long_credit  how_long_work
# 0   39             0.50          12.90
# 1   32             0.42           4.22
# 2   53             1.83          12.15
# 3   42             3.08           5.73
# 4   42             2.17           5.77
#
# [5 rows x 22 columns]

# %%
dataset.edu_type.unique()
# Out:
# array(['Higher education', 'Secondary / secondary special',
#        'Incomplete higher', 'Lower secondary', 'Academic degree'],
#       dtype=object)

# %%
dataset3 = dataset.copy()

# %%
dataset.columns
# Out:
# Index(['gender', 'car', 'reality', 'child_num', 'income_total', 'income_type',
#        'edu_type', 'family_type', 'house_type', 'work_phone', 'phone', 'email',
#        'occyp_type', 'family_size', 'AGE', 'how_long_credit', 'how_long_work'],
#       dtype='object')

# %%
dataset.drop(['index','FLAG_MOBIL','begin_month','DAYS_BIRTH',"DAYS_EMPLOYED"], axis=1, inplace=True)

# %%
dataset['income_total'] = dataset['income_total'].map(np.log1p)

# %%
final_data = pd.get_dummies(dataset)

# %%
train_data.shape
# Out:
# (26457, 20)

# %%
final_data.shape
# Out:
# (36453, 55)

# %%
x_train = final_data.iloc[:26453]
x_test = final_data.iloc[26453:]

# %%
y_train = train_data["credit"]
y_train = y_train.drop([8462, 9021, 10731, 25390]).reset_index(drop=True)

# %%
# y_train = pd.get_dummies(y_train)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=350,random_state=123)

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=350, random_state=123)

# %%
pred = rfc.predict_proba(x_test)

# %%
pred
# Out:
# array([[0.04857143, 0.17428571, 0.77714286],
#        [0.52      , 0.19809524, 0.28190476],
#        [0.03428571, 0.03857143, 0.92714286],
#        ...,
#        [0.00285714, 0.02857143, 0.96857143],
#        [0.62428571, 0.25285714, 0.12285714],
#        [0.12019048, 0.266     , 0.61380952]])

# %%
submission[["0","1","2"]] = pred

# %%
type(submission[["0","1","2"]])
# Out:
# pandas.core.frame.DataFrame

# %%
# n_estimator 350
submission.to_csv("baseline_rf_350.csv", index=False)

# %%
# 카드를 여러장 발급 받았는지의 여부
